# %% [markdown]
# # Validation Demo
#
# Use this notebook to validate narrative metric behavior on known company-year examples.

# %%
from models.lm_tone import score_lm_tone
from models.readability import gunning_fog

sample = 'We achieved strong growth but face uncertainty and execution risk.'
score_lm_tone(sample), gunning_fog(sample)
